# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv('iris.csv')
df
# Out:
#      Unnamed: 0  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width  \
# 0             1           5.1          3.5           1.4          0.2
# 1             2           4.9          3.0           1.4          0.2
# 2             3           4.7          3.2           1.3          0.2
# 3             4           4.6          3.1           1.5          0.2
# 4             5           5.0          3.6           1.4          0.2
# ..          ...           ...          ...           ...          ...
# 145         146           6.7          3.0           5.2          2.3
# 146         147           6.3          2.5           5.0          1.9
# 147         148           6.5          3.0           5.2          2.0
# 148         149           6.2          3.4           5.4          2.3
# 149         150           5.9          3.0           5.1          1.8
#
#        Species
# 0       setosa
# 1       setosa
# 2       setosa
# 3       setosa
# 4       setosa
# ..         ...
# ...

# %%
features = df.drop('Species', axis = 1)

scaler = StandardScaler()
data_scaled = scaler.fit_transform(features)

# %%
wcss = []

for i in range(1,11):
    kmeans = KMeans(n_clusters = i, random_state = 0)
    kmeans.fit(data_scaled)
    wcss.append(kmeans.inertia_)

# %%
plt.figure(figsize=(8, 6))
plt.plot(range(1,11), wcss, marker = 'o', color = 'b')
plt.title('Elbow Method for Optimal K')
plt.xlabel('Number of Clusters (K)')
plt.ylabel('wcss')
plt.grid(True)
plt.show()

# %%
kmeans = KMeans(n_clusters = 3, init = 'k-means++', max_iter = 300, n_init = 10, random_state = 0)
ymeans = kmeans.fit_predict(data_scaled)

# %%
plt.scatter(data_scaled[y_kmeans == 0, 0], data_scaled[y_kmeans == 0, 1], s = 100, c = 'purple', label = 'Iris-setosa')
plt.scatter(data_scaled[y_kmeans == 1, 0], data_scaled[y_kmeans == 1, 1], s = 100, c = 'orange', label = 'Iris-versicolour')
plt.scatter(data_scaled[y_kmeans == 2, 0], data_scaled[y_kmeans == 2, 1], s = 100, c = 'green', label = 'Iris-virginica')

plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s =100, c = 'red', label = 'Centroids')
plt.legend()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv('iris.csv')
df
# Out:
#      Unnamed: 0  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width  \
# 0             1           5.1          3.5           1.4          0.2
# 1             2           4.9          3.0           1.4          0.2
# 2             3           4.7          3.2           1.3          0.2
# 3             4           4.6          3.1           1.5          0.2
# 4             5           5.0          3.6           1.4          0.2
# ..          ...           ...          ...           ...          ...
# 145         146           6.7          3.0           5.2          2.3
# 146         147           6.3          2.5           5.0          1.9
# 147         148           6.5          3.0           5.2          2.0
# 148         149           6.2          3.4           5.4          2.3
# 149         150           5.9          3.0           5.1          1.8
#
#        Species
# 0       setosa
# 1       setosa
# 2       setosa
# 3       setosa
# 4       setosa
# ..         ...
# ...

# %%
features = df.drop('Species', axis = 1)

scaler = StandardScaler()
data_scaled = scaler.fit_transform(features)

# %%
wcss = []

for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, random_state = 0)
    kmeans.fit(data_scaled)
    wcss.append(kmeans.inertia_)

# %%
plt.figure(figsize = (8, 16),)
plt.plot(range(1, 11), wcss, marker = 'o', color = 'b')
plt.title('Elbow Method for Optimal K')
plt.xlabel('Number of Clusters (K)')
plt.ylabel('wcss')
plt.grid(True)
plt.show()

# %%
kmeans = KMeans(n_clusters = 3, init = 'k-means++', max_iter = 300, n_init = 10, random_state = 0)
y_means = kmeans.fit_predict(data_scaled)

# %%
plt.scatter(data_scaled[y_kmeans == 0, 0], data_scaled[y_kmeans == 0, 1], s = 100, c = 'purple', label = 'Iris-setosa')
plt.scatter(data_scaled[y_kmeans == 1, 0], data_scaled[y_kmeans == 1, 1], s = 100, c = 'purple', label = 'Iris-versicolour')
plt.scatter(data_scaled[y_kmeans == 2, 0], data_scaled[y_kmeans == 2, 1], s = 100, c = 'purple', label = 'Iris-virginica')

plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s =100, c = 'red', label = 'Centroids')
plt.legend()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv('iris.csv')
df
# Out:
#      Unnamed: 0  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width  \
# 0             1           5.1          3.5           1.4          0.2
# 1             2           4.9          3.0           1.4          0.2
# 2             3           4.7          3.2           1.3          0.2
# 3             4           4.6          3.1           1.5          0.2
# 4             5           5.0          3.6           1.4          0.2
# ..          ...           ...          ...           ...          ...
# 145         146           6.7          3.0           5.2          2.3
# 146         147           6.3          2.5           5.0          1.9
# 147         148           6.5          3.0           5.2          2.0
# 148         149           6.2          3.4           5.4          2.3
# 149         150           5.9          3.0           5.1          1.8
#
#        Species
# 0       setosa
# 1       setosa
# 2       setosa
# 3       setosa
# 4       setosa
# ..         ...
# ...

# %%
features = df.drop('Species', axis = 1)

scaler = StandardScaler()
data_scaled = scaler.fit_transform(features)

# %%
wcss = []

for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, random_state = 0)
    kmeans.fit(data_scaled)
    wcss.append(kmeans.inertia_)

# %%
plt.figure(figsize = (8, 6))
plt.plot(range(1, 11), wcss, marker ='o', color = 'red')
plt.title('Optimal number of Clusters')
plt.xlabel('Number of clusters')
plt.ylabel('wcss')
plt.grid(True)
plt.show()

# %%
kmeans = KMeans(n_clusters = 3, init = 'k-means++', max_iter = 300, n_init = 100, random_state = 0)
y_means = kmeans.fit_predict(data_scaled)

# %%
plt.scatter(data_scaled[y_means == 0, 0], data_scaled[y_means == 0, 1], s = 100, c = 'purple', label = 'Iris-setosa')
plt.scatter(data_scaled[y_means == 1, 0], data_scaled[y_means == 1, 1], s = 100, c = 'red', label = 'Iris-versicolour')
plt.scatter(data_scaled[y_means == 2, 0], data_scaled[y_means == 2, 1], s = 100, c = 'blue', label = 'Iris-virginica')

plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s = 100, c = 'orange', label = 'centroid')
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv("iris.csv")
df
# Out:
#      Unnamed: 0  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width  \
# 0             1           5.1          3.5           1.4          0.2
# 1             2           4.9          3.0           1.4          0.2
# 2             3           4.7          3.2           1.3          0.2
# 3             4           4.6          3.1           1.5          0.2
# 4             5           5.0          3.6           1.4          0.2
# ..          ...           ...          ...           ...          ...
# 145         146           6.7          3.0           5.2          2.3
# 146         147           6.3          2.5           5.0          1.9
# 147         148           6.5          3.0           5.2          2.0
# 148         149           6.2          3.4           5.4          2.3
# 149         150           5.9          3.0           5.1          1.8
#
#        Species
# 0       setosa
# 1       setosa
# 2       setosa
# 3       setosa
# 4       setosa
# ..         ...
# ...

# %%
X = df.drop('Species', axis = 1)
sc = StandardScaler()
data_scaled = sc.fit_transform(X)

# %%
wcss = []

for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, random_state = 0)
    kmeans.fit(data_scaled)
    wcss.append(kmeans.inertia_)

# %%
plt.figure(figsize = (8, 6))
plt.plot(range(1, 11), wcss, marker = 'o', color = 'red')
plt.title("Optimal number of Clusters")
plt.xlabel("Number of clusters")
plt.ylabel("WCSS")
plt.grid(True)
plt.show()

# %%
kmeans = KMeans(n_clusters=3, init='k-means++', max_iter = 300, n_init = 100, random_state= 0 )
y_pred = kmeans.fit_predict(data_scaled)

# %%
plt.scatter(data_scaled[y_pred == 0, 0], data_scaled[y_pred == 0, 1], s = 100, c = 'purple', label = 'Iris-setosa')
plt.scatter(data_scaled[y_pred == 1, 0], data_scaled[y_pred == 1, 1], s = 100, c = 'purple', label = 'Iris-setosa')
plt.scatter(data_scaled[y_pred == 2, 0], data_scaled[y_pred == 2, 1], s = 100, c = 'purple', label = 'Iris-setosa')

plt.scatter(kmeans.cluster_centers_[:,0],kmeans.cluster_centers_[:, 1], s = 100, c = 'red', label = 'centroid')
plt.legend()
plt.show()

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
df = pd.read_csv("iris.csv")
df
# Out:
#      Unnamed: 0  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width  \
# 0             1           5.1          3.5           1.4          0.2
# 1             2           4.9          3.0           1.4          0.2
# 2             3           4.7          3.2           1.3          0.2
# 3             4           4.6          3.1           1.5          0.2
# 4             5           5.0          3.6           1.4          0.2
# ..          ...           ...          ...           ...          ...
# 145         146           6.7          3.0           5.2          2.3
# 146         147           6.3          2.5           5.0          1.9
# 147         148           6.5          3.0           5.2          2.0
# 148         149           6.2          3.4           5.4          2.3
# 149         150           5.9          3.0           5.1          1.8
#
#        Species
# 0       setosa
# 1       setosa
# 2       setosa
# 3       setosa
# 4       setosa
# ..         ...
# ...

# %%
X = df.drop('Species', axis = 1)

sc = StandardScaler()
data_scaled = sc.fit_transform(X)

# %%
wcss = []

for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, random_state= 0)
    kmeans.fit(data_scaled)
    wcss.append(kmeans.inertia_)

# %%
plt.figure(figsize= (8, 6))
plt.plot(range(1, 11), wcss, marker = 'o', color = 'red')
plt.title("optimal number of clusters")
plt.xlabel("Number of clusters")
plt.ylabel("WCSS")
plt.grid(True)
plt.show()

# %%
kmeans = KMeans(n_clusters = 3, init = 'k-means++', max_iter = 300, n_init = 100, random_state= 0)
y_pred = kmeans.fit_predict(data_scaled)

# %%
plt.scatter(data_scaled[y_pred == 0, 0], data_scaled[y_pred == 0, 1], s = 100, c = 'purple', label = "setosa")
plt.scatter(data_scaled[y_pred == 1, 0], data_scaled[y_pred == 1, 1], s = 100, c = 'purple', label = "setosa")
plt.scatter(data_scaled[y_pred == 2, 0], data_scaled[y_pred == 2, 1], s = 100, c = 'purple', label = "setosa")

plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s = 100, c = 'red', label = "centroid")
plt.legend()
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

# %%
df = pd.read_csv("iris.csv")
df
# Out:
#      Unnamed: 0  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width  \
# 0             1           5.1          3.5           1.4          0.2
# 1             2           4.9          3.0           1.4          0.2
# 2             3           4.7          3.2           1.3          0.2
# 3             4           4.6          3.1           1.5          0.2
# 4             5           5.0          3.6           1.4          0.2
# ..          ...           ...          ...           ...          ...
# 145         146           6.7          3.0           5.2          2.3
# 146         147           6.3          2.5           5.0          1.9
# 147         148           6.5          3.0           5.2          2.0
# 148         149           6.2          3.4           5.4          2.3
# 149         150           5.9          3.0           5.1          1.8
#
#        Species
# 0       setosa
# 1       setosa
# 2       setosa
# 3       setosa
# 4       setosa
# ..         ...
# ...

# %%
X = df.drop('Species', axis = 1)

sc = StandardScaler()
data_scaled = sc.fit_transform(X)

# %%
wcss = []

for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, random_state= 0)
    kmeans.fit(data_scaled)
    wcss.append(kmeans.inertia_)

# %%
plt.figure(figsize= (8, 6))
plt.plot(range(1, 11), wcss, marker = 'o', color = 'red')
plt.title("optimal number of clusters")
plt.xlabel("Number of clusters")
plt.ylabel("WCSS")
plt.grid(True)
plt.show()

# %%
kmeans = KMeans(n_clusters= 3, init='k-means++', max_iter=300, n_init=100, random_state=0)
y_pred = kmeans.fit_predict(data_scaled)

# %%
plt.scatter(data_scaled[y_pred == 0, 0], data_scaled[y_pred == 0, 1], s = 100, c = 'purple', label = "setosa")
plt.scatter(data_scaled[y_pred == 1, 0], data_scaled[y_pred == 1, 1], s = 100, c = 'purple', label = "setosa")
plt.scatter(data_scaled[y_pred == 2, 0], data_scaled[y_pred == 2, 1], s = 100, c = 'purple', label = "setosa")

plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s = 100, c = 'red', label = 'red')
plt.legend()
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

# %%
df = pd.read_csv("iris.csv")
df
# Out:
#      Unnamed: 0  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width  \
# 0             1           5.1          3.5           1.4          0.2
# 1             2           4.9          3.0           1.4          0.2
# 2             3           4.7          3.2           1.3          0.2
# 3             4           4.6          3.1           1.5          0.2
# 4             5           5.0          3.6           1.4          0.2
# ..          ...           ...          ...           ...          ...
# 145         146           6.7          3.0           5.2          2.3
# 146         147           6.3          2.5           5.0          1.9
# 147         148           6.5          3.0           5.2          2.0
# 148         149           6.2          3.4           5.4          2.3
# 149         150           5.9          3.0           5.1          1.8
#
#        Species
# 0       setosa
# 1       setosa
# 2       setosa
# 3       setosa
# 4       setosa
# ..         ...
# ...

# %%
X = df.drop('Species', axis = 1)

sc = StandardScaler()
data_scaled = sc.fit_transform(X)

# %%
wcss = []

for i in range(1, 11):
    kmeans = KMeans(n_clusters= i, random_state= 0)
    kmeans.fit(data_scaled)
    wcss.append(kmeans.inertia_)

# %%
plt.figure(figsize=(8, 6))
plt.plot(range(1, 11), wcss, marker = 'o', color = 'red')
plt.title("optimal number of clusters")
plt.xlabel("Number of clusters")
plt.ylabel("WCSS")
plt.grid(True)
plt.show()

# %%
kmeans = KMeans(n_clusters=3, init='k-means++', max_iter=300, n_init = 100, random_state=0)
y_pred = kmeans.fit_predict(data_scaled)

# %%
plt.scatter(data_scaled[y_pred == 0, 0], data_scaled[y_pred == 0, 1], s = 100, c = 'purple', label = 'satosa')
plt.scatter(data_scaled[y_pred == 1, 0], data_scaled[y_pred == 1, 1], s = 100, c = 'purple', label = 'satosa')
plt.scatter(data_scaled[y_pred == 2, 0], data_scaled[y_pred == 2, 1], s = 100, c = 'purple', label = 'satosa')

plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s = 100, c = 'red', label = 'Centroid')
plt.legend()
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.cluster import KMeans

# %%
df = pd.read_csv("iris.csv")
df
# Out:
#      Unnamed: 0  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width  \
# 0             1           5.1          3.5           1.4          0.2
# 1             2           4.9          3.0           1.4          0.2
# 2             3           4.7          3.2           1.3          0.2
# 3             4           4.6          3.1           1.5          0.2
# 4             5           5.0          3.6           1.4          0.2
# ..          ...           ...          ...           ...          ...
# 145         146           6.7          3.0           5.2          2.3
# 146         147           6.3          2.5           5.0          1.9
# 147         148           6.5          3.0           5.2          2.0
# 148         149           6.2          3.4           5.4          2.3
# 149         150           5.9          3.0           5.1          1.8
#
#        Species
# 0       setosa
# 1       setosa
# 2       setosa
# 3       setosa
# 4       setosa
# ..         ...
# ...

# %%
X = df.drop('Species', axis = 1)
sc = StandardScaler()
data_scaled = sc.fit_transform(X)

# %%
wcss = []

for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, random_state=0)
    kmeans.fit(data_scaled)
    wcss.append(kmeans.inertia_)

# %%
plt.figure(figsize=(8, 6))
plt.plot(range(1, 11), wcss, marker = 'o', color = 'red')
plt.title("optimal number of clusters")
plt.xlabel("Number of clusters")
plt.ylabel("WCSS")
plt.grid(True)
plt.show()

# %%
kmeans = KMeans(n_clusters=3, init='k-means++', max_iter=300, n_init=100, random_state=0)
y_pred = kmeans.fit_predict(data_scaled)

# %%
plt.scatter(data_scaled[y_pred == 0, 0], data_scaled[y_pred == 0, 1], s = 100, c = 'purple', label = 'satosa')
plt.scatter(data_scaled[y_pred == 1, 0], data_scaled[y_pred == 1, 1], s = 100, c = 'purple', label = 'satosa')
plt.scatter(data_scaled[y_pred == 2, 0], data_scaled[y_pred == 2, 1], s = 100, c = 'purple', label = 'satosa')

plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s = 100, c = 'red', label = 'Centroid')
plt.legend()
plt.show()

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("iris.csv")
df.head()
# Out:
#    Unnamed: 0  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           1           5.1          3.5           1.4          0.2  setosa
# 1           2           4.9          3.0           1.4          0.2  setosa
# 2           3           4.7          3.2           1.3          0.2  setosa
# 3           4           4.6          3.1           1.5          0.2  setosa
# 4           5           5.0          3.6           1.4          0.2  setosa

# %%
# df.pop('Unnamed: 0')

# %%
X = df.drop('Species', axis = 1)

sc = StandardScaler()
data_scaled = sc.fit_transform(X)

# %%
wcss = []

for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, random_state=0)
    kmeans.fit(data_scaled)
    wcss.append(kmeans.inertia_)

# %%
plt.figure(figsize=(8, 6))
plt.plot(range(1, 11), wcss, marker = 'o', color = 'red')
plt.title("optimal number of clusters")
plt.xlabel("Number of clusters")
plt.ylabel("WCSS")
plt.grid(True)
plt.show()

# %%
kmeans = KMeans(n_clusters=3, init='k-means++', max_iter=300, n_init=100, random_state= 0)
y_pred = kmeans.fit_predict(data_scaled)

# %%
plt.scatter(data_scaled[y_pred == 0, 0], data_scaled[y_pred == 0, 1], s = 100, c = 'purple', label = 'satosa')
plt.scatter(data_scaled[y_pred == 1, 0], data_scaled[y_pred == 1, 1], s = 100, c = 'purple', label = 'satosa')
plt.scatter(data_scaled[y_pred == 2, 0], data_scaled[y_pred == 2, 1], s = 100, c = 'purple', label = 'satosa')

plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s = 100, c = 'red', label = 'Centroid')
plt.legend()
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv("iris.csv")
df.head()
# Out:
#    Unnamed: 0  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           1           5.1          3.5           1.4          0.2  setosa
# 1           2           4.9          3.0           1.4          0.2  setosa
# 2           3           4.7          3.2           1.3          0.2  setosa
# 3           4           4.6          3.1           1.5          0.2  setosa
# 4           5           5.0          3.6           1.4          0.2  setosa

# %%
X = df.drop('Species', axis = 1)

sc = StandardScaler()
data_scaled = sc.fit_transform(X)

# %%
wcss = []

for i in range(1,11):
    kmeans = KMeans(n_clusters = i, random_state = 0)
    kmeans.fit(data_scaled)
    wcss.append(kmeans.inertia_)

# %%
plt.figure(figsize = (8, 6))
plt.plot(range(1, 11), wcss, marker = 'o', color = 'red')
plt.title("optimal number of clusters")
plt.xlabel("Number of clusters")
plt.ylabel("WCSS")
plt.grid(True)
plt.show()

# %%
kmeans = KMeans(n_clusters=3, init='k-means++',max_iter=300, n_init = 100, random_state = 0)
y_pred = kmeans.fit_predict(data_scaled)

# %%
plt.scatter(data_scaled[y_pred == 0, 0], data_scaled[y_pred == 0, 1], s = 100, c = 'purple', label = 'Satosa')
plt.scatter(data_scaled[y_pred == 1, 0], data_scaled[y_pred == 1, 1], s = 100, c = 'orange', label = 'Satosa')
plt.scatter(data_scaled[y_pred == 2, 0], data_scaled[y_pred == 2, 1], s = 100, c = 'yellow', label = 'Satosa')

plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s = 100, c = 'red', label = "Centoid")
plt.legend()
plt.show()
